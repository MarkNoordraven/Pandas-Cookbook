# %%
import pandas as pd

# %%
movie = pd.read_csv('data/movie.csv', index_col='movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie_2_hours = movie['duration'] > 120
movie_2_hours.head()
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: duration, dtype: bool

# %%
movie_2_hours.sum()
# Out:
# 1039

# %%
movie_2_hours.mean()
# Out:
# 0.2113506916192026

# %%
movie_2_hours.std()
# Out:
# 0.40830808172850497

# %%
movie['duration'].dropna().gt(120).mean()
# Out:
# 0.21199755152009794

# %%
movie['duration'].dropna().lt(120).mean()
# Out:
# 0.772699449092022

# %%
movie_2_hours.describe()
# Out:
# count      4916
# unique        2
# top       False
# freq       3877
# Name: duration, dtype: object

# %%
movie['director_name'].value_counts(normalize=True)
# Out:
# Steven Spielberg           0.005401
# Woody Allen                0.004570
# Clint Eastwood             0.004155
# Martin Scorsese            0.004155
# Ridley Scott               0.003324
# Spike Lee                  0.003324
# Renny Harlin               0.003116
# Steven Soderbergh          0.003116
# Tim Burton                 0.002908
# Oliver Stone               0.002908
# Joel Schumacher            0.002700
# Barry Levinson             0.002700
# Robert Rodriguez           0.002700
# Ron Howard                 0.002700
# Robert Zemeckis            0.002700
# Kevin Smith                0.002493
# Michael Bay                0.002493
# Brian De Palma             0.002493
# Tony Scott                 0.002493
# Shawn Levy                 0.002285
# Rob Reiner                 0.002285
# Chris Columbus             0.002285
# Sam Raimi                  0.002285
# Richard Donner             0.002285
# Richard Linklater          0.002285
# Francis Ford Coppola       0.002285
# ...

# %%
movie_2_hours.value_counts(normalize = True)
# Out:
# False    0.788649
# True     0.211351
# Name: duration, dtype: float64

# %%
actors = movie[['actor_1_facebook_likes', 'actor_2_facebook_likes']]
len(actors)
# Out:
# 4916

# %%
actors = actors.dropna()
len(actors)
# Out:
# 4903

# %%
(movie['actor_1_facebook_likes'] > movie['actor_2_facebook_likes']).mean()
# Out:
# 0.9751830756712775

# %%
criteria1 = movie.imdb_score > 8
criteria2 = movie.content_rating == 'PG-13'
criteria3 = ((movie.title_year < 2000) | (movie.title_year > 2009))

# %%
criteria_final = criteria1 & criteria2 & criteria3
criteria_final.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %%
criteria_final
# Out:
# movie_title
# Avatar                                         False
# Pirates of the Caribbean: At World's End       False
# Spectre                                        False
# The Dark Knight Rises                           True
# Star Wars: Episode VII - The Force Awakens     False
# John Carter                                    False
# Spider-Man 3                                   False
# Tangled                                        False
# Avengers: Age of Ultron                        False
# Harry Potter and the Half-Blood Prince         False
# Batman v Superman: Dawn of Justice             False
# Superman Returns                               False
# Quantum of Solace                              False
# Pirates of the Caribbean: Dead Man's Chest     False
# The Lone Ranger                                False
# Man of Steel                                   False
# The Chronicles of Narnia: Prince Caspian       False
# ...

# %%
crit_a1 = movie.imdb_score > 8
crit_a2 = movie.content_rating == 'PG-13'
crit_a3 = ((movie.title_year < 2000) | (movie.title_year > 2009))
final_crit_a = crit_a1 & crit_a2 & crit_a3

# %%
final_crit_a
# Out:
# movie_title
# Avatar                                         False
# Pirates of the Caribbean: At World's End       False
# Spectre                                        False
# The Dark Knight Rises                           True
# Star Wars: Episode VII - The Force Awakens     False
# John Carter                                    False
# Spider-Man 3                                   False
# Tangled                                        False
# Avengers: Age of Ultron                        False
# Harry Potter and the Half-Blood Prince         False
# Batman v Superman: Dawn of Justice             False
# Superman Returns                               False
# Quantum of Solace                              False
# Pirates of the Caribbean: Dead Man's Chest     False
# The Lone Ranger                                False
# Man of Steel                                   False
# The Chronicles of Narnia: Prince Caspian       False
# ...

# %%
movie.loc[final_crit_a]
# Out:
#                                                    color       director_name  \
# movie_title
# The Dark Knight Rises                              Color   Christopher Nolan
# The Avengers                                       Color         Joss Whedon
# Captain America: Civil War                         Color       Anthony Russo
# Guardians of the Galaxy                            Color          James Gunn
# Interstellar                                       Color   Christopher Nolan
# Inception                                          Color   Christopher Nolan
# The Martian                                        Color        Ridley Scott
# Jurassic Park                                      Color    Steven Spielberg
# Forrest Gump                             Black and White     Robert Zemeckis
# Indiana Jones and the Last Crusade                 Color    Steven Spielberg
# The Sixth Sense                                    Color  M. Night Shyamalan
# ...

# %%
crit_b1 = movie.imdb_score < 5
crit_b2 = movie.content_rating == 'R'
crit_b3 = ((movie.title_year >= 2000) & (movie.title_year <=2010))
final_crit_b = crit_b1 & crit_b2 & crit_b3

# %%
final_crit_all = final_crit_a | final_crit_b
final_crit_all.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# dtype: bool

# %%
movie[final_crit_all]
# Out:
#                                                               color  \
# movie_title
# The Dark Knight Rises                                         Color
# The Avengers                                                  Color
# Captain America: Civil War                                    Color
# Guardians of the Galaxy                                       Color
# Interstellar                                                  Color
# Inception                                                     Color
# The Martian                                                   Color
# Town & Country                                                Color
# Sex and the City 2                                            Color
# Rollerball                                                    Color
# Ballistic: Ecks vs. Sever                                     Color
# Basic Instinct 2                                              Color
# Jurassic Park                                                 Color
# ...

# %%
movie.loc[final_crit_all]
# Out:
#                                                               color  \
# movie_title
# The Dark Knight Rises                                         Color
# The Avengers                                                  Color
# Captain America: Civil War                                    Color
# Guardians of the Galaxy                                       Color
# Interstellar                                                  Color
# Inception                                                     Color
# The Martian                                                   Color
# Town & Country                                                Color
# Sex and the City 2                                            Color
# Rollerball                                                    Color
# Ballistic: Ecks vs. Sever                                     Color
# Basic Instinct 2                                              Color
# Jurassic Park                                                 Color
# ...

# %%
cols = ['imdb_score', 'content_rating', 'title_year']
movie_filtered = movie.loc[final_crit_all, cols]
movie_filtered.head(10)
# Out:
#                             imdb_score content_rating  title_year
# movie_title
# The Dark Knight Rises              8.5          PG-13      2012.0
# The Avengers                       8.1          PG-13      2012.0
# Captain America: Civil War         8.2          PG-13      2016.0
# Guardians of the Galaxy            8.1          PG-13      2014.0
# Interstellar                       8.6          PG-13      2014.0
# Inception                          8.8          PG-13      2010.0
# The Martian                        8.1          PG-13      2015.0
# Town & Country                     4.4              R      2001.0
# Sex and the City 2                 4.3              R      2010.0
# Rollerball                         3.0              R      2002.0

# %%
final_crit_a2 = (movie.imdb_score > 8) & \
                (movie.content_rating == 'PG-13') & \
                ((movie.title_year < 2000) | (movie.title_year > 2009))
final_crit_a2.equals(final_crit_a)
# Out:
# True

# %%
college = pd.read_csv('data/college.csv')
college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY         ...          \
# 0        0.0         0     424.0     420.0           0.0         ...
# 1        0.0         0     570.0     565.0           0.0         ...
# 2        0.0         1       NaN       NaN           1.0         ...
# 3        0.0         0     595.0     590.0           0.0         ...
# 4        0.0         0     425.0     430.0           0.0         ...
#
#    UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# ...

# %%
college[college['STABBR'] == 'TX'].head()
# Out:
#                             INSTNM        CITY STABBR  HBCU  MENONLY  \
# 3610  Abilene Christian University     Abilene     TX   0.0      0.0
# 3611       Alvin Community College       Alvin     TX   0.0      0.0
# 3612              Amarillo College    Amarillo     TX   0.0      0.0
# 3613              Angelina College      Lufkin     TX   0.0      0.0
# 3614       Angelo State University  San Angelo     TX   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# 3610        0.0         1     530.0     545.0           0.0
# 3611        0.0         0       NaN       NaN           0.0
# 3612        0.0         0       NaN       NaN           0.0
# 3613        0.0         0       NaN       NaN           0.0
# 3614        0.0         0     475.0     490.0           0.0
#
#              ...          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# 3610         ...             0.0454    0.0423     0.0045    0.0468         1
# ...

# %%
college2 = college.set_index('STABBR')
college2.loc['TX'].head()
# Out:
#                               INSTNM        CITY  HBCU  MENONLY  WOMENONLY  \
# STABBR
# TX      Abilene Christian University     Abilene   0.0      0.0        0.0
# TX           Alvin Community College       Alvin   0.0      0.0        0.0
# TX                  Amarillo College    Amarillo   0.0      0.0        0.0
# TX                  Angelina College      Lufkin   0.0      0.0        0.0
# TX           Angelo State University  San Angelo   0.0      0.0        0.0
#
#         RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  \
# STABBR
# TX             1     530.0     545.0           0.0  3572.0
# TX             0       NaN       NaN           0.0  4682.0
# TX             0       NaN       NaN           0.0  9346.0
# TX             0       NaN       NaN           0.0  3825.0
# TX             0     475.0     490.0           0.0  5290.0
#
#                ...          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# STABBR         ...
# ...

# %%
# %timeit college[college['STABBR'] == 'TX']
# Out:
# 1.04 ms ± 2.04 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college2.loc['TX']
# Out:
# 565 µs ± 1.63 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit college2 = college.set_index('STABBR')
# Out:
# 1.1 ms ± 11 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
states = ['TX', 'CA', 'NY']
# %timeit college[college['STABBR'].isin(states)]
college[college['STABBR'].isin(states)]
# Out:
# 883 µs ± 19.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
#                                                  INSTNM              CITY  \
# 192                           Academy of Art University     San Francisco
# 193              ITT Technical Institute-Rancho Cordova    Rancho Cordova
# 194      Academy of Chinese Culture and Health Sciences           Oakland
# 195            The Academy of Radio and TV Broadcasting  Huntington Beach
# 196                Avalon School of Cosmetology-Alameda           Alameda
# 197                                  College of Alameda           Alameda
# 198                               Allan Hancock College       Santa Maria
# 199       American Academy of Dramatic Arts-Los Angeles       Los Angeles
# 200               American Baptist Seminary of the West          Berkeley
# 201                American Film Institute Conservatory       Los Angeles
# 202                             American Beauty College       West Covina
# ...

# %%
# %timeit college2.loc[states]
college2.loc[states]
# Out:
# 1.05 ms ± 18.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
#                                                    INSTNM             CITY  \
# STABBR
# TX                           Abilene Christian University          Abilene
# TX                                Alvin Community College            Alvin
# TX                                       Amarillo College         Amarillo
# TX                                       Angelina College           Lufkin
# TX                                Angelo State University       San Angelo
# TX                              Arlington Baptist College        Arlington
# TX                             Arlington Career Institute    Grand Prairie
# TX                           The Art Institute of Houston          Houston
# TX                                         Austin College          Sherman
# TX                      Austin Community College District           Austin
# ...

# %%
college2.index.is_monotonic
# Out:
# False

# %%
college2.sort_index()
# Out:
#                                                    INSTNM               CITY  \
# STABBR
# AK                              Charter College-Anchorage          Anchorage
# AK                                  Alaska Career College          Anchorage
# AK                 AVTEC-Alaska's Institute of Technology             Seward
# AK                              Alaska Pacific University          Anchorage
# AK                         University of Alaska Southeast             Juneau
# AK                         University of Alaska Fairbanks          Fairbanks
# AK                                      Ilisagvik College             Barrow
# AK                                   Alaska Bible College             Palmer
# AK                               Alaska Christian College           Soldotna
# AK                         University of Alaska Anchorage          Anchorage
# AL                                  Fortis College-Dothan             Dothan
# ...

# %%
college2.index.is_monotonic
# Out:
# False

# %%
college3 = college2.sort_index()
college3.head()
# Out:
#                                         INSTNM       CITY  HBCU  MENONLY  \
# STABBR
# AK                   Charter College-Anchorage  Anchorage   0.0      0.0
# AK                       Alaska Career College  Anchorage   0.0      0.0
# AK      AVTEC-Alaska's Institute of Technology     Seward   0.0      0.0
# AK                   Alaska Pacific University  Anchorage   0.0      0.0
# AK              University of Alaska Southeast     Juneau   0.0      0.0
#
#         WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  \
# STABBR
# AK            0.0         0       NaN       NaN           0.0  3256.0
# AK            0.0         0       NaN       NaN           0.0   479.0
# AK            0.0         0       NaN       NaN           0.0   889.0
# AK            0.0         1     555.0     503.0           0.0   275.0
# AK            0.0         0       NaN       NaN           0.0  1428.0
#
#                ...          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# ...

# %%
# %timeit college[college['STABBR'] == 'TX']
# %timeit college2.loc['TX']
# %timeit college3.loc['TX']
# Out:
# 1.1 ms ± 33.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 566 µs ± 3.21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 209 µs ± 3.65 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
college_unique = college.set_index('INSTNM')
college_unique.index.is_unique
# Out:
# True

# %%
college[college['INSTNM'] == 'Stanford University']
# Out:
#                    INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4217  Stanford University  Stanford     CA   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY         ...          \
# 4217         0     730.0     745.0           0.0         ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 4217     0.1067    0.0819     0.0031       0.0         1   0.1556    0.1256
#
#       UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4217   0.0401            86000               12782
#
# [1 rows x 27 columns]

# %%
college_unique.loc['Stanford University']
# Out:
# CITY                  Stanford
# STABBR                      CA
# HBCU                         0
# MENONLY                      0
# WOMENONLY                    0
# RELAFFIL                     0
# SATVRMID                   730
# SATMTMID                   745
# DISTANCEONLY                 0
# UGDS                      7018
# UGDS_WHITE              0.3752
# UGDS_BLACK              0.0591
# UGDS_HISP               0.1607
# UGDS_ASIAN              0.1979
# UGDS_AIAN               0.0114
# UGDS_NHPI               0.0038
# UGDS_2MOR               0.1067
# UGDS_NRA                0.0819
# UGDS_UNKN               0.0031
# PPTUG_EF                     0
# CURROPER                     1
# PCTPELL                 0.1556
# PCTFLOAN                0.1256
# UG25ABV                 0.0401
# MD_EARN_WNE_P10          86000
# GRAD_DEBT_MDN_SUPP       12782
# Name: Stanford University, dtype: object

# %%
# %timeit college[college['INSTNM'] == 'Stanford University']

# %timeit college_unique.loc['Stanford University']
# Out:
# 999 µs ± 24.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 163 µs ± 2.07 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
college.index = college['CITY'] + ', ' + college['STABBR']
college = college.sort_index()

# %%
college.head()
# Out:
#                                  INSTNM      CITY STABBR  HBCU  MENONLY  \
# ARTESIA, CA           Angeles Institute   ARTESIA     CA   0.0      0.0
# Aberdeen, SD       Presentation College  Aberdeen     SD   0.0      0.0
# Aberdeen, SD  Northern State University  Aberdeen     SD   0.0      0.0
# Aberdeen, WA       Grays Harbor College  Aberdeen     WA   0.0      0.0
# Abilene, TX   Hardin-Simmons University   Abilene     TX   0.0      0.0
#
#               WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# ARTESIA, CA         0.0         0       NaN       NaN           0.0
# Aberdeen, SD        0.0         1     440.0     480.0           0.0
# Aberdeen, SD        0.0         0     480.0     475.0           0.0
# Aberdeen, WA        0.0         0       NaN       NaN           0.0
# Abilene, TX         0.0         1     508.0     515.0           0.0
#
#                      ...          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# ...

# %%
college.loc['Miami, FL'].head()
# Out:
#                                               INSTNM   CITY STABBR  HBCU  \
# Miami, FL        New Professions Technical Institute  Miami     FL   0.0
# Miami, FL               Management Resources College  Miami     FL   0.0
# Miami, FL                   Strayer University-Doral  Miami     FL   NaN
# Miami, FL                   Keiser University- Miami  Miami     FL   NaN
# Miami, FL  George T Baker Aviation Technical College  Miami     FL   0.0
#
#            MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# Miami, FL      0.0        0.0         0       NaN       NaN           0.0
# Miami, FL      0.0        0.0         0       NaN       NaN           0.0
# Miami, FL      NaN        NaN         1       NaN       NaN           NaN
# Miami, FL      NaN        NaN         1       NaN       NaN           NaN
# Miami, FL      0.0        0.0         0       NaN       NaN           0.0
#
#                   ...          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# ...

# %%
# %%timeit
crit1 = college['CITY'] == 'Miami'
crit2 = college['STABBR'] == 'FL'
college[crit1 & crit2]
# Out:
# 1.78 ms ± 16.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
college.loc['Miami, FL']
# Out:
# 210 µs ± 6.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
slb = pd.read_csv('data/slb_stock.csv', index_col='Date', parse_dates=['Date'])
slb.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  66.39  67.20  66.12  67.11   5771234
# 2010-01-05  66.99  67.62  66.73  67.30   7366270
# 2010-01-06  67.17  68.94  67.03  68.80   9949946
# 2010-01-07  68.49  69.81  68.21  69.51   7700297
# 2010-01-08  69.19  72.00  69.09  70.65  13487621

# %%
slb_close = slb['Close']
slb_close
# Out:
# Date
# 2010-01-04    67.11
# 2010-01-05    67.30
# 2010-01-06    68.80
# 2010-01-07    69.51
# 2010-01-08    70.65
# 2010-01-11    70.65
# 2010-01-12    69.59
# 2010-01-13    70.85
# 2010-01-14    71.29
# 2010-01-15    70.83
# 2010-01-19    70.93
# 2010-01-20    69.09
# 2010-01-21    68.31
# 2010-01-22    65.24
# 2010-01-25    65.81
# 2010-01-26    65.75
# 2010-01-27    65.70
# 2010-01-28    64.63
# 2010-01-29    63.46
# 2010-02-01    64.79
# 2010-02-02    66.12
# 2010-02-03    65.99
# 2010-02-04    62.50
# 2010-02-05    62.06
# 2010-02-08    62.12
# 2010-02-09    63.76
# 2010-02-10    63.65
# 2010-02-11    64.76
# 2010-02-12    64.30
# 2010-02-16    65.65
#               ...
# 2017-06-02    68.96
# 2017-06-05    69.27
# 2017-06-06    69.97
# 2017-06-07    68.67
# 2017-06-08    68.31
# 2017-06-09    69.68
# 2017-06-12    69.31
# 2017-06-13    69.35
# 2017-06-14    68.18
# 2017-06-15    67.33
# 2017-06-16    68.58
# 2017-06-19    68.10
# 2017-06-20    66.75
# 2017-06-21    65.47
# ...

# %%
slb_summary = slb_close.describe(percentiles=[0.1, 0.9])
slb_summary
# Out:
# count    1895.000000
# mean       79.121905
# std        11.767802
# min        51.750000
# 10%        64.892000
# 50%        78.000000
# 90%        93.248000
# max       117.950000
# Name: Close, dtype: float64

# %%
slb_close.describe()
# Out:
# count    1895.000000
# mean       79.121905
# std        11.767802
# min        51.750000
# 25%        71.320000
# 50%        78.000000
# 75%        86.125000
# max       117.950000
# Name: Close, dtype: float64

# %%
slb_summary.loc['min']
# Out:
# 51.75

# %%
list(slb['Open'])
# Out:
# [66.39,
#  66.99,
#  67.17,
#  68.49,
#  69.19,
#  71.3,
#  69.2,
#  69.71,
#  70.11,
#  71.22,
#  69.87,
#  69.77,
#  69.02,
#  67.39,
#  65.69,
#  65.25,
#  65.46,
#  66.12,
#  65.4,
#  64.3,
#  65.5,
#  65.72,
#  64.99,
#  62.61,
#  62.23,
#  63.13,
#  63.61,
#  63.56,
#  63.7,
#  65.33,
#  65.83,
#  65.88,
#  63.36,
#  60.09,
#  61.5,
#  61.13,
#  60.09,
#  61.13,
#  61.83,
#  61.59,
#  63.39,
#  63.24,
#  63.41,
#  63.83,
#  64.04,
#  64.01,
#  64.06,
#  64.17,
#  64.1,
#  64.81,
#  65.77,
#  66.5,
#  65.43,
#  62.7,
#  63.53,
#  62.41,
#  62.85,
#  61.12,
#  62.32,
#  63.3,
#  63.43,
#  64.24,
#  65.03,
#  65.89,
#  66.85,
#  65.48,
#  67.07,
#  66.2,
#  66.4,
#  66.0,
#  67.01,
#  66.46,
#  65.18,
#  66.4,
#  67.89,
#  67.26,
#  70.14,
#  72.6,
#  72.39,
#  70.77,
#  72.27,
#  73.33,
#  71.12,
#  69.55,
#  67.36,
#  67.12,
#  64.59,
#  65.52,
#  66.03,
#  67.31,
#  67.07,
#  66.54,
#  65.22,
#  65.11,
#  63.45,
#  60.92,
#  57.79,
#  60.13,
#  56.05,
#  59.33,
#  60.58,
# ...

# %%
slb.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  66.39  67.20  66.12  67.11   5771234
# 2010-01-05  66.99  67.62  66.73  67.30   7366270
# 2010-01-06  67.17  68.94  67.03  68.80   9949946
# 2010-01-07  68.49  69.81  68.21  69.51   7700297
# 2010-01-08  69.19  72.00  69.09  70.65  13487621

# %%
upper_10 = slb_summary.loc['90%']
lower_10 = slb_summary.loc['10%']
criteria = (slb_close < lower_10) | (slb_close > upper_10)
slb_top_bottom_10 = slb_close[criteria]
slb_top_bottom_10
# Out:
# Date
# 2010-01-28    64.63
# 2010-01-29    63.46
# 2010-02-01    64.79
# 2010-02-04    62.50
# 2010-02-05    62.06
# 2010-02-08    62.12
# 2010-02-09    63.76
# 2010-02-10    63.65
# 2010-02-11    64.76
# 2010-02-12    64.30
# 2010-02-19    63.90
# 2010-02-22    61.57
# 2010-02-23    60.88
# 2010-02-24    60.91
# 2010-02-25    60.81
# 2010-02-26    61.10
# 2010-03-01    61.42
# 2010-03-02    62.81
# 2010-03-03    63.23
# 2010-03-04    62.88
# 2010-03-05    63.81
# 2010-03-08    64.48
# 2010-03-09    64.10
# 2010-03-10    64.20
# 2010-03-11    63.90
# 2010-03-12    64.54
# 2010-03-15    64.31
# 2010-03-19    64.32
# 2010-03-22    63.49
# 2010-03-23    63.03
#               ...
# 2014-10-30    97.62
# 2014-10-31    98.66
# 2014-11-03    96.52
# 2014-11-04    94.16
# 2014-11-05    96.64
# 2014-11-06    96.98
# 2014-11-07    98.73
# 2014-11-10    98.29
# 2014-11-11    98.36
# 2014-11-12    97.43
# 2014-11-13    94.85
# 2014-11-14    95.32
# 2014-11-17    95.63
# 2014-11-18    95.28
# ...

# %%
import matplotlib

slb_close.plot(color='black', figsize=(12,6))
slb_top_bottom_10.plot(marker='o', style=' ', ms=4, color='lightgray')


xmin = criteria.index[0]
xmax = criteria.index[-1]
matplotlib.pyplot.hlines(y=[lower_10, upper_10], xmin=xmin, xmax=xmax, color='lightgray');

# %%
slb_close.plot(color='black', figsize=(12,6))
matplotlib.pyplot.hlines(y=[lower_10, upper_10], xmin=xmin, xmax=xmax, color='lightgray')
matplotlib.pyplot.fill_between(x=criteria.index, y1=lower_10, y2=slb_close.values, color='black')
matplotlib.pyplot.fill_between(x=criteria.index, y1=lower_10, y2=slb_close.values, where=slb_close<lower_10, color='lightgray')
matplotlib.pyplot.fill_between(x=criteria.index, y1=upper_10, y2=slb_close.values, where=slb_close>upper_10, color='lightgray')

# %%
employee = pd.read_csv('data/employee.csv')
employee.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# ...

# %%
employee.DEPARTMENT.value_counts()
# Out:
# Houston Police Department-HPD     638
# Houston Fire Department (HFD)     384
# Public Works & Engineering-PWE    343
# Health & Human Services           110
# Houston Airport System (HAS)      106
# Parks & Recreation                 74
# Solid Waste Management             43
# Library                            36
# Fleet Management Department        36
# Admn. & Regulatory Affairs         29
# Municipal Courts Department        28
# Human Resources Dept.              24
# Houston Emergency Center (HEC)     23
# Housing and Community Devp.        22
# General Services Department        22
# Legal Department                   17
# Dept of Neighborhoods (DON)        17
# City Council                       11
# Finance                            10
# Houston Information Tech Svcs       9
# Planning & Development              7
# City Controller's Office            5
# Mayor's Office                      5
# Convention and Entertainment        1
# Name: DEPARTMENT, dtype: int64

# %%
employee.DEPARTMENT.value_counts(normalize=True)*100
# Out:
# Houston Police Department-HPD     31.90
# Houston Fire Department (HFD)     19.20
# Public Works & Engineering-PWE    17.15
# Health & Human Services            5.50
# Houston Airport System (HAS)       5.30
# Parks & Recreation                 3.70
# Solid Waste Management             2.15
# Library                            1.80
# Fleet Management Department        1.80
# Admn. & Regulatory Affairs         1.45
# Municipal Courts Department        1.40
# Human Resources Dept.              1.20
# Houston Emergency Center (HEC)     1.15
# Housing and Community Devp.        1.10
# General Services Department        1.10
# Legal Department                   0.85
# Dept of Neighborhoods (DON)        0.85
# City Council                       0.55
# Finance                            0.50
# Houston Information Tech Svcs      0.45
# Planning & Development             0.35
# City Controller's Office           0.25
# Mayor's Office                     0.25
# ...

# %%
employee.DEPARTMENT.value_counts(sort=False)
# Out:
# Planning & Development              7
# Library                            36
# Houston Emergency Center (HEC)     23
# Health & Human Services           110
# Solid Waste Management             43
# City Controller's Office            5
# Parks & Recreation                 74
# Legal Department                   17
# City Council                       11
# Admn. & Regulatory Affairs         29
# Houston Information Tech Svcs       9
# Houston Airport System (HAS)      106
# Finance                            10
# Convention and Entertainment        1
# Human Resources Dept.              24
# Fleet Management Department        36
# Mayor's Office                      5
# General Services Department        22
# Public Works & Engineering-PWE    343
# Municipal Courts Department        28
# Dept of Neighborhoods (DON)        17
# Houston Police Department-HPD     638
# Housing and Community Devp.        22
# Houston Fire Department (HFD)     384
# Name: DEPARTMENT, dtype: int64

# %%
employee.DEPARTMENT.value_counts(ascending=False)
# Out:
# Houston Police Department-HPD     638
# Houston Fire Department (HFD)     384
# Public Works & Engineering-PWE    343
# Health & Human Services           110
# Houston Airport System (HAS)      106
# Parks & Recreation                 74
# Solid Waste Management             43
# Library                            36
# Fleet Management Department        36
# Admn. & Regulatory Affairs         29
# Municipal Courts Department        28
# Human Resources Dept.              24
# Houston Emergency Center (HEC)     23
# Housing and Community Devp.        22
# General Services Department        22
# Legal Department                   17
# Dept of Neighborhoods (DON)        17
# City Council                       11
# Finance                            10
# Houston Information Tech Svcs       9
# Planning & Development              7
# City Controller's Office            5
# Mayor's Office                      5
# Convention and Entertainment        1
# Name: DEPARTMENT, dtype: int64

# %%
employee.GENDER.value_counts()
# Out:
# Male      1397
# Female     603
# Name: GENDER, dtype: int64

# %%
employee.BASE_SALARY.describe().astype(int)
# Out:
# count      1886
# mean      55767
# std       21693
# min       24960
# 25%       40170
# 50%       54461
# 75%       66614
# max      275000
# Name: BASE_SALARY, dtype: int64

# %%
employee.BASE_SALARY.describe()
# Out:
# count      1886.000000
# mean      55767.931601
# std       21693.706679
# min       24960.000000
# 25%       40170.000000
# 50%       54461.000000
# 75%       66614.000000
# max      275000.000000
# Name: BASE_SALARY, dtype: float64

# %%
depts = ['Houston Police Department-HPD',
         'Houston Fire Department (HFD)']

criteria_dept = employee.DEPARTMENT.isin(depts)

criteria_gender = employee.GENDER == 'Female'

criteria_sal = (employee.BASE_SALARY >= 80000) & (employee.BASE_SALARY <= 120000)

# %%
criteria_final = (criteria_dept &
                  criteria_gender &
                  criteria_sal)

# %%
select_columns = ['UNIQUE_ID', 'DEPARTMENT', 'GENDER', 'BASE_SALARY']
employee.loc[criteria_final, select_columns]
# Out:
#       UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61           61  Houston Fire Department (HFD)  Female      96668.0
# 136         136  Houston Police Department-HPD  Female      81239.0
# 367         367  Houston Police Department-HPD  Female      86534.0
# 474         474  Houston Police Department-HPD  Female      91181.0
# 513         513  Houston Police Department-HPD  Female      81239.0
# 564         564  Houston Police Department-HPD  Female      81239.0
# 595         595  Houston Police Department-HPD  Female      99953.0
# 937         937  Houston Police Department-HPD  Female      81239.0
# 954         954  Houston Police Department-HPD  Female      91181.0
# 1118       1118  Houston Police Department-HPD  Female     104455.0
# 1519       1519  Houston Police Department-HPD  Female      91181.0
# 1565       1565  Houston Police Department-HPD  Female      81239.0
# 1622       1622  Houston Police Department-HPD  Female      91181.0

# %%
criteria_sal = employee.BASE_SALARY.between(80000, 120000)

# %%
top_5_depts = employee.DEPARTMENT.value_counts().index[:5]

# %%
criteria = ~employee.DEPARTMENT.isin(top_5_depts)
criteria.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# Name: DEPARTMENT, dtype: bool

# %%
amzn = pd.read_csv('data/amzn_stock.csv', index_col='Date', parse_dates=['Date'])
amzn.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2010-01-04  136.25  136.61  133.14  133.90   7600543
# 2010-01-05  133.43  135.48  131.81  134.69   8856456
# 2010-01-06  134.60  134.73  131.65  132.25   7180977
# 2010-01-07  132.01  132.32  128.80  130.00  11030124
# 2010-01-08  130.56  133.68  129.03  133.52   9833829

# %%
amzn_daily_return = amzn.Close.pct_change()
amzn_daily_return.head()
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.005900
# 2010-01-06   -0.018116
# 2010-01-07   -0.017013
# 2010-01-08    0.027077
# Name: Close, dtype: float64

# %%
amzn_daily_return = amzn_daily_return.dropna()
amzn_daily_return.hist(bins=20)

# %%
mean = amzn_daily_return.mean()
std = amzn.daily_return.std()
abs_z_score = amzn_daily_return.sub(mean).abs().div(std)
abs_z_score
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-361209644946> in <module>
# ----> 1 mean = amzn.daily_return.mean()
#       2 std = amzn.daily_return.std()
#       3 abs_z_score = amzn_daily_return.sub(mean).abs().div(std)
#       4 abs_z_score
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'daily_return'
