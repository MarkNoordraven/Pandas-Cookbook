# %%
import pandas as pd

# %%
names = pd.read_csv('data/names.csv')
names.head()
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2

# %%
new_data_list = ['Aria', 1]
names.loc[4] = new_data_list

# %%
names
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2
# 4      Aria    1

# %%
names.loc['five'] = ['Zach', 3]
names
# Out:
#           Name  Age
# 0     Cornelia   70
# 1        Abbas   69
# 2     Penelope    4
# 3         Niko    2
# 4         Aria    1
# five      Zach    3

# %%
names.loc[len(names)] = {'Name':'Zayd',
                         'Age':2}
names
# Out:
#           Name  Age
# 0     Cornelia   70
# 1        Abbas   69
# 2     Penelope    4
# 3         Niko    2
# 4         Aria    1
# five      Zach    3
# 6         Zayd    2

# %%
names.loc[len(names)] = {'Name':'Dean',
                         'Age':32}
names
# Out:
#           Name  Age
# 0     Cornelia   70
# 1        Abbas   69
# 2     Penelope    4
# 3         Niko    2
# 4         Aria    1
# five      Zach    3
# 6         Zayd    2
# 7         Dean   32

# %%
names = pd.read_csv('data/names.csv')

# %%
names.append({'Name':'Aria',
              'Age':1}, ignore_index = True)
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2
# 4      Aria    1

# %%
names.index = ['Canada', 'Canada','USA','USA']
names
# Out:
#             Name  Age
# Canada  Cornelia   70
# Canada     Abbas   69
# USA     Penelope    4
# USA         Niko    2

# %%
s = pd.Series({'Name':'Zach',
               'Age':3},
               name = len(names))
s
# Out:
# Name    Zach
# Age        3
# Name: 4, dtype: object

# %%
names.append(s)
# Out:
#             Name  Age
# Canada  Cornelia   70
# Canada     Abbas   69
# USA     Penelope    4
# USA         Niko    2
# 4           Zach    3

# %%
s1 = pd.Series({'Name': 'Zach',
                'Age': 3},
               name = len(names))
s2 = pd.Series({'Name': 'Zayd',
                'Age': 2},
               name = 'USA')
names.append([s1,s2])
# Out:
#             Name  Age
# Canada  Cornelia   70
# Canada     Abbas   69
# USA     Penelope    4
# USA         Niko    2
# 4           Zach    3
# USA         Zayd    2

# %%
bbal_16 = pd.read_csv('data/baseball16.csv')
bbal_16.head()
# Out:
#     playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...    RBI  \
# 0  altuvjo01    2016      1    HOU   AL  161  640  108  216  42  ...   96.0
# 1  bregmal01    2016      1    HOU   AL   49  201   31   53  13  ...   34.0
# 2  castrja01    2016      1    HOU   AL  113  329   41   69  16  ...   32.0
# 3  correca01    2016      1    HOU   AL  153  577   76  158  36  ...   96.0
# 4  gattiev01    2016      1    HOU   AL  128  447   58  112  19  ...   72.0
#
#      SB    CS  BB     SO   IBB  HBP   SH   SF  GIDP
# 0  30.0  10.0  60   70.0  11.0  7.0  3.0  7.0  15.0
# 1   2.0   0.0  15   52.0   0.0  0.0  0.0  1.0   1.0
# 2   2.0   1.0  45  123.0   0.0  1.0  1.0  0.0   9.0
# 3  13.0   3.0  75  139.0   5.0  5.0  0.0  3.0  12.0
# 4   2.0   1.0  43  127.0   6.0  4.0  0.0  5.0  12.0
#
# [5 rows x 22 columns]

# %%
data_dict = bbal_16.iloc[0].to_dict()
data_dict
# Out:
# {'playerID': 'altuvjo01',
#  'yearID': 2016,
#  'stint': 1,
#  'teamID': 'HOU',
#  'lgID': 'AL',
#  'G': 161,
#  'AB': 640,
#  'R': 108,
#  'H': 216,
#  '2B': 42,
#  '3B': 5,
#  'HR': 24,
#  'RBI': 96.0,
#  'SB': 30.0,
#  'CS': 10.0,
#  'BB': 60,
#  'SO': 70.0,
#  'IBB': 11.0,
#  'HBP': 7.0,
#  'SH': 3.0,
#  'SF': 7.0,
#  'GIDP': 15.0}

# %%
import numpy as np

new_data_dict = {k: '' if isinstance(v, str) else np.nan for k,v in data_dict.items()}
new_data_dict
# Out:
# {'playerID': '',
#  'yearID': nan,
#  'stint': nan,
#  'teamID': '',
#  'lgID': '',
#  'G': nan,
#  'AB': nan,
#  'R': nan,
#  'H': nan,
#  '2B': nan,
#  '3B': nan,
#  'HR': nan,
#  'RBI': nan,
#  'SB': nan,
#  'CS': nan,
#  'BB': nan,
#  'SO': nan,
#  'IBB': nan,
#  'HBP': nan,
#  'SH': nan,
#  'SF': nan,
#  'GIDP': nan}

# %%
for k,v in data_dict.items():
    print(f' k is {k} en v is {v}')
# Out:
#  k is playerID en v is altuvjo01
#  k is yearID en v is 2016
#  k is stint en v is 1
#  k is teamID en v is HOU
#  k is lgID en v is AL
#  k is G en v is 161
#  k is AB en v is 640
#  k is R en v is 108
#  k is H en v is 216
#  k is 2B en v is 42
#  k is 3B en v is 5
#  k is HR en v is 24
#  k is RBI en v is 96.0
#  k is SB en v is 30.0
#  k is CS en v is 10.0
#  k is BB en v is 60
#  k is SO en v is 70.0
#  k is IBB en v is 11.0
#  k is HBP en v is 7.0
#  k is SH en v is 3.0
#  k is SF en v is 7.0
#  k is GIDP en v is 15.0

# %%
random_data = []
for i in range(1000):
    d = dict()
    for k, v in data_dict.items():
        if isinstance(v, str):
            d[k] = np.random.choice(list('abcde'))
        else:
            d[k] = np.random.randint(10)
    random_data.append(pd.Series(d, name = i + len(bbal_16)))

# %%
random_data[0].head()
# Out:
# playerID    b
# yearID      2
# stint       5
# teamID      e
# lgID        b
# Name: 16, dtype: object

# %%
# %%timeit
bbal_16_copy = bbal_16.copy()
for row in random_data:
    bbal_16_copy = bbal_16_copy.append(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-45b674f89901> in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', 'bbal_16_copy = bbal_16.copy()\nfor row in random_data:\n    bbal_16_copy = bbal_16_copy.append(row)\n')
#
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2321             magic_arg_s = self.var_expand(line, stack_depth)
#    2322             with self.builtin_trap:
# -> 2323                 result = fn(magic_arg_s, cell)
#    2324             return result
#    2325
#
# <decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1133                     break
#    1134
# -> 1135         all_runs = timer.repeat(repeat, number)
#    1136         best = min(all_runs) / number
#    1137         worst = max(all_runs) / number
#
# /usr/lib/python3.6/timeit.py in repeat(self, repeat, number)
#     204         r = []
#     205         for i in range(repeat):
# --> 206             t = self.timeit(number)
#     207             r.append(t)
#     208         return r
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     158         gc.disable()
#     159         try:
# --> 160             timing = self.inner(it, self.timer)
#     161         finally:
#     162             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6194                               index=index,
#    6195                               columns=combined_columns)
# -> 6196             other = other._convert(datetime=True, timedelta=True)
#    6197             if not self.columns.equals(combined_columns):
#    6198                 self = self.reindex(columns=combined_columns)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _convert(self, datetime, numeric, timedelta, coerce, copy)
#    5152             self._data.convert(datetime=datetime, numeric=numeric,
#    5153                                timedelta=timedelta, coerce=coerce,
# -> 5154                                copy=copy)).__finalize__(self)
#    5155
#    5156     def convert_objects(self, convert_dates=True, convert_numeric=False,
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals.py in convert(self, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
# -> 3717         return self.apply('convert', **kwargs)
#    3718
#    3719     def replace(self, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3586         bm = self.__class__(result_blocks, axes or self.axes,
#    3587                             do_integrity_check=do_integrity_check)
# -> 3588         bm._consolidate_inplace()
#    3589         return bm
#    3590
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate_inplace(self)
#    4101     def _consolidate_inplace(self):
#    4102         if not self.is_consolidated():
# -> 4103             self.blocks = tuple(_consolidate(self.blocks))
#    4104             self._is_consolidated = True
#    4105             self._known_consolidated = True
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate(blocks)
#    5066     new_blocks = []
#    5067     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 5068         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
#    5069                                       _can_consolidate=_can_consolidate)
#    5070         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals.py in <lambda>(x)
#    5061
#    5062     # sort by _can_consolidate, dtype
# -> 5063     gkey = lambda x: x._consolidate_key
#    5064     grouper = itertools.groupby(sorted(blocks, key=gkey), gkey)
#    5065
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate_key(self)
#     166     @property
#     167     def _consolidate_key(self):
# --> 168         return (self._can_consolidate, self.dtype.name)
#     169
#     170     @property
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_dtype.py in _name_get(dtype)
#     332
#     333     # append bit counts to str, unicode, and void
# --> 334     if np.issubdtype(dtype, np.flexible) and not _isunsized(dtype):
#     335         name += "{}".format(dtype.itemsize * 8)
#     336
#
# ~/.local/lib/python3.6/site-packages/numpy/core/numerictypes.py in issubdtype(arg1, arg2)
#     391     """
#     392     if not issubclass_(arg1, generic):
# --> 393         arg1 = dtype(arg1).type
#     394     if not issubclass_(arg2, generic):
#     395         arg2_orig = arg2
#
# KeyboardInterrupt:

# %%
# %%timeit
bbal_16_copy = bbal_16.copy()
bbal_16_copy = bbal_16_copy.append(random_data)

# %%
stocks_2016 = pd.read_csv('data/stocks_2016.csv',
                          index_col = 'Symbol')
stocks_2016
# Out:
#         Shares  Low  High
# Symbol
# AAPL        80   95   110
# TSLA        50   80   130
# WMT         40   55    70

# %%
stocks_2017 = pd.read_csv('data/stocks_2017.csv',
                          index_col = 'Symbol')
stocks_2017
# Out:
#         Shares  Low  High
# Symbol
# AAPL        50  120   140
# GE         100   30    40
# IBM         87   75    95
# SLB         20   55    85
# TXN        500   15    23
# TSLA       100  100   300

# %%
s_list = [ stocks_2016, stocks_2017]
pd.concat(s_list)
# Out:
#         Shares  Low  High
# Symbol
# AAPL        80   95   110
# TSLA        50   80   130
# WMT         40   55    70
# AAPL        50  120   140
# GE         100   30    40
# IBM         87   75    95
# SLB         20   55    85
# TXN        500   15    23
# TSLA       100  100   300

# %%
pd.concat(s_list, keys = ['2016', '2017'],
          names = ['Year', 'Symbol'])
# Out:
#              Shares  Low  High
# Year Symbol
# 2016 AAPL        80   95   110
#      TSLA        50   80   130
#      WMT         40   55    70
# 2017 AAPL        50  120   140
#      GE         100   30    40
#      IBM         87   75    95
#      SLB         20   55    85
#      TXN        500   15    23
#      TSLA       100  100   300

# %%
pd.concat(s_list,
          keys = ['2016', '2017'],
          axis = 'columns',
          sort = True,
          names = ['Year', None])
# Out:
# Year   2016                2017
#      Shares   Low   High Shares    Low   High
# AAPL   80.0  95.0  110.0   50.0  120.0  140.0
# GE      NaN   NaN    NaN  100.0   30.0   40.0
# IBM     NaN   NaN    NaN   87.0   75.0   95.0
# SLB     NaN   NaN    NaN   20.0   55.0   85.0
# TSLA   50.0  80.0  130.0  100.0  100.0  300.0
# TXN     NaN   NaN    NaN  500.0   15.0   23.0
# WMT    40.0  55.0   70.0    NaN    NaN    NaN

# %%
pd.concat(s_list,
          join = 'inner',
          axis = 'columns',
          names = 'Year',
          sort = True)
# Out:
#         Shares  Low  High  Shares  Low  High
# Symbol
# AAPL        80   95   110      50  120   140
# TSLA        50   80   130     100  100   300

# %%
stocks_2016.append(stocks_2017)
# Out:
#         Shares  Low  High
# Symbol
# AAPL        80   95   110
# TSLA        50   80   130
# WMT         40   55    70
# AAPL        50  120   140
# GE         100   30    40
# IBM         87   75    95
# SLB         20   55    85
# TXN        500   15    23
# TSLA       100  100   300

# %%
trump_url = 'https://en.wikipedia.org/wiki/List_of_generation_VIII_Pok%C3%A9mon'

# %%
df_list = pd.read_html(trump_url)

# %%
len(df_list)
# Out:
# 4

# %%
df_list[3]
# Out:
#                         0                                                  1
# 0      vtePokémon species                                                NaN
# 1     Generation I (1996)  Bulbasaur Venusaur Charmander Charizard Squirt...
# 2    Generation II (1999)  Chikorita Togepi Unown Entei Lugia Celebi Unus...
# 3   Generation III (2002)  Blaziken Mudkip Absol Latias and Latios Rayqua...
# 4    Generation IV (2006)                            Lucario Giratina Arceus
# 5     Generation V (2010)                                                NaN
# 6    Generation VI (2013)                                Xerneas and Yveltal
# 7   Generation VII (2016)   Yungoos and Gumshoos Mimikyu Meltan and Melmetal
# 8  Generation VIII (2019)                                                NaN

# %%
df_list = pd.read_html(trump_url,
                       match = 'Yungoos',
                       header = 0)
df_list
# Out:
# [       vtePokémon species                                         Unnamed: 1
#  0     Generation I (1996)  Bulbasaur Venusaur Charmander Charizard Squirt...
#  1    Generation II (1999)  Chikorita Togepi Unown Entei Lugia Celebi Unus...
#  2   Generation III (2002)  Blaziken Mudkip Absol Latias and Latios Rayqua...
#  3    Generation IV (2006)                            Lucario Giratina Arceus
#  4     Generation V (2010)                                                NaN
#  5    Generation VI (2013)                                Xerneas and Yveltal
#  6   Generation VII (2016)   Yungoos and Gumshoos Mimikyu Meltan and Melmetal
#  7  Generation VIII (2019)                                                NaN]

# %%
df_list[0].columns
# Out:
# Index(['vtePokémon species', 'Unnamed: 1'], dtype='object')

# %%
df_list2 = df_list[0]

# %%
df_list2.columns = ['Pokémon species', 'Pokémon']
df_list2.head()
# Out:
#          Pokémon species                                            Pokémon
# 0    Generation I (1996)  Bulbasaur Venusaur Charmander Charizard Squirt...
# 1   Generation II (1999)  Chikorita Togepi Unown Entei Lugia Celebi Unus...
# 2  Generation III (2002)  Blaziken Mudkip Absol Latias and Latios Rayqua...
# 3   Generation IV (2006)                            Lucario Giratina Arceus
# 4    Generation V (2010)                                                NaN

# %%
from IPython.display import display_html

# %%
years = 2016,2017,2018

# %%
stock_tables = [pd.read_csv('data/stocks_{}.csv'.format(year),
                           index_col = 'Symbol') for year in years]

# %%
type(stock_tables)
# Out:
# list

# %%
stock_tables = [] 

for year in years:
    print(year)
    stock_tables.append(pd.read_csv('data/stocks_{}.csv'.format(year), index_col = 'Symbol'))

stock_tables[2]
# Out:
# 2016
# 2017
# 2018
#         Shares  Low  High
# Symbol
# AAPL        40  135   170
# AMZN         8  900  1125
# TSLA        50  220   400

# %%
stocks_2018
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-4da7d4126646> in <module>
# ----> 1 stocks_2018
#
# NameError: name 'stocks_2018' is not defined

# %%
def display_frames(frames, num_spaces = 0):
    t_style = '<table style = "display: inline;"'
    tables_html = [df.to_html().replace('<table', t_style) for df in frames]
    
    space = '&nbsp;' * num_spaces
#     print(tables_html)
    display_html(space.join(tables_html), raw = True)

# %%
display_frames(stock_tables, 30)
# Out:
# <table style = "display: inline;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Shares</th>
#       <th>Low</th>
#       <th>High</th>
#     </tr>
#     <tr>
#       <th>Symbol</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAPL</th>
#       <td>80</td>
#       <td>95</td>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>TSLA</th>
#       <td>50</td>
#       <td>80</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>WMT</th>
#       <td>40</td>
#       <td>55</td>
#       <td>70</td>
#     </tr>
#   </tbody>
# </table>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<table style = "display: inline;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Shares</th>
#       <th>Low</th>
#       <th>High</th>
#     </tr>
#     <tr>
#       <th>Symbol</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAPL</th>
#       <td>50</td>
#       <td>120</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>GE</th>
#       <td>100</td>
#       <td>30</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>IBM</th>
#       <td>87</td>
#       <td>75</td>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>SLB</th>
#       <td>20</td>
#       <td>55</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>TXN</th>
#       <td>500</td>
#       <td>15</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>TSLA</th>
#       <td>100</td>
#       <td>100</td>
#       <td>300</td>
#     </tr>
#   </tbody>
# </table>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<table style = "display: inline;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Shares</th>
#       <th>Low</th>
#       <th>High</th>
#     </tr>
#     <tr>
#       <th>Symbol</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AAPL</th>
#       <td>40</td>
#       <td>135</td>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>AMZN</th>
#       <td>8</td>
#       <td>900</td>
#       <td>1125</td>
#     </tr>
#     <tr>
#       <th>TSLA</th>
#       <td>50</td>
#       <td>220</td>
#       <td>400</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.concat(stock_tables, keys = [2016, 2017, 2018])
# Out:
#              Shares  Low  High
#      Symbol
# 2016 AAPL        80   95   110
#      TSLA        50   80   130
#      WMT         40   55    70
# 2017 AAPL        50  120   140
#      GE         100   30    40
#      IBM         87   75    95
#      SLB         20   55    85
#      TXN        500   15    23
#      TSLA       100  100   300
# 2018 AAPL        40  135   170
#      AMZN         8  900  1125
#      TSLA        50  220   400

# %%
pd.concat(dict(zip(years, stock_tables)), axis = 'columns')
# Out:
# /home/mark/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#        2016                2017                 2018
#      Shares   Low   High Shares    Low   High Shares    Low    High
# AAPL   80.0  95.0  110.0   50.0  120.0  140.0   40.0  135.0   170.0
# AMZN    NaN   NaN    NaN    NaN    NaN    NaN    8.0  900.0  1125.0
# GE      NaN   NaN    NaN  100.0   30.0   40.0    NaN    NaN     NaN
# IBM     NaN   NaN    NaN   87.0   75.0   95.0    NaN    NaN     NaN
# SLB     NaN   NaN    NaN   20.0   55.0   85.0    NaN    NaN     NaN
# TSLA   50.0  80.0  130.0  100.0  100.0  300.0   50.0  220.0   400.0
# TXN     NaN   NaN    NaN  500.0   15.0   23.0    NaN    NaN     NaN
# WMT    40.0  55.0   70.0    NaN    NaN    NaN    NaN    NaN     NaN

# %%
stocks_2016.join(stocks_2017, 
                 lsuffix = '_2016',
                 rsuffix = '_2017',
                 how = 'outer')
# Out:
#         Shares_2016  Low_2016  High_2016  Shares_2017  Low_2017  High_2017
# Symbol
# AAPL           80.0      95.0      110.0         50.0     120.0      140.0
# GE              NaN       NaN        NaN        100.0      30.0       40.0
# IBM             NaN       NaN        NaN         87.0      75.0       95.0
# SLB             NaN       NaN        NaN         20.0      55.0       85.0
# TSLA           50.0      80.0      130.0        100.0     100.0      300.0
# TXN             NaN       NaN        NaN        500.0      15.0       23.0
# WMT            40.0      55.0       70.0          NaN       NaN        NaN

# %%
other = [stock_tables[1].add_suffix('_2017'),
         stock_tables[2].add_suffix('_2018')]

# %%
# stocks_2017
stock_tables[2]
# Out:
#         Shares  Low  High
# Symbol
# AAPL        40  135   170
# AMZN         8  900  1125
# TSLA        50  220   400

# %%
stocks_2016.add_suffix('_2016').join(other,
                                     how = 'outer')
# Out:
#       Shares_2016  Low_2016  High_2016  Shares_2017  Low_2017  High_2017  \
# AAPL         80.0      95.0      110.0         50.0     120.0      140.0
# AMZN          NaN       NaN        NaN          NaN       NaN        NaN
# GE            NaN       NaN        NaN        100.0      30.0       40.0
# IBM           NaN       NaN        NaN         87.0      75.0       95.0
# SLB           NaN       NaN        NaN         20.0      55.0       85.0
# TSLA         50.0      80.0      130.0        100.0     100.0      300.0
# TXN           NaN       NaN        NaN        500.0      15.0       23.0
# WMT          40.0      55.0       70.0          NaN       NaN        NaN
#
#       Shares_2018  Low_2018  High_2018
# AAPL         40.0     135.0      170.0
# AMZN          8.0     900.0     1125.0
# GE            NaN       NaN        NaN
# IBM           NaN       NaN        NaN
# SLB           NaN       NaN        NaN
# TSLA         50.0     220.0      400.0
# TXN           NaN       NaN        NaN
# WMT           NaN       NaN        NaN

# %%
stock_join = stocks_2016.add_suffix('_2016').join(other,
                                     how = 'outer')

# %%
stock_concat = pd.concat(dict(zip(years, stock_tables)),
                         axis = 'columns',
                         sort = True)
stock_concat
# Out:
#        2016                2017                 2018
#      Shares   Low   High Shares    Low   High Shares    Low    High
# AAPL   80.0  95.0  110.0   50.0  120.0  140.0   40.0  135.0   170.0
# AMZN    NaN   NaN    NaN    NaN    NaN    NaN    8.0  900.0  1125.0
# GE      NaN   NaN    NaN  100.0   30.0   40.0    NaN    NaN     NaN
# IBM     NaN   NaN    NaN   87.0   75.0   95.0    NaN    NaN     NaN
# SLB     NaN   NaN    NaN   20.0   55.0   85.0    NaN    NaN     NaN
# TSLA   50.0  80.0  130.0  100.0  100.0  300.0   50.0  220.0   400.0
# TXN     NaN   NaN    NaN  500.0   15.0   23.0    NaN    NaN     NaN
# WMT    40.0  55.0   70.0    NaN    NaN    NaN    NaN    NaN     NaN

# %%
level_1 = stock_concat.columns.get_level_values(1)
level_1
# Out:
# Index(['Shares', 'Low', 'High', 'Shares', 'Low', 'High', 'Shares', 'Low',
#        'High'],
#       dtype='object')

# %%
level_0 = stock_concat.columns.get_level_values(0).astype(str)
level_0
# Out:
# Index(['2016', '2016', '2016', '2017', '2017', '2017', '2018', '2018', '2018'], dtype='object')

# %%
stock_concat.columns = level_1 + '_' + level_0

# %%
stock_concat
# Out:
#       Shares_2016  Low_2016  High_2016  Shares_2017  Low_2017  High_2017  \
# AAPL         80.0      95.0      110.0         50.0     120.0      140.0
# AMZN          NaN       NaN        NaN          NaN       NaN        NaN
# GE            NaN       NaN        NaN        100.0      30.0       40.0
# IBM           NaN       NaN        NaN         87.0      75.0       95.0
# SLB           NaN       NaN        NaN         20.0      55.0       85.0
# TSLA         50.0      80.0      130.0        100.0     100.0      300.0
# TXN           NaN       NaN        NaN        500.0      15.0       23.0
# WMT          40.0      55.0       70.0          NaN       NaN        NaN
#
#       Shares_2018  Low_2018  High_2018
# AAPL         40.0     135.0      170.0
# AMZN          8.0     900.0     1125.0
# GE            NaN       NaN        NaN
# IBM           NaN       NaN        NaN
# SLB           NaN       NaN        NaN
# TSLA         50.0     220.0      400.0
# TXN           NaN       NaN        NaN
# WMT           NaN       NaN        NaN

# %%
stock_join
# Out:
#       Shares_2016  Low_2016  High_2016  Shares_2017  Low_2017  High_2017  \
# AAPL         80.0      95.0      110.0         50.0     120.0      140.0
# AMZN          NaN       NaN        NaN          NaN       NaN        NaN
# GE            NaN       NaN        NaN        100.0      30.0       40.0
# IBM           NaN       NaN        NaN         87.0      75.0       95.0
# SLB           NaN       NaN        NaN         20.0      55.0       85.0
# TSLA         50.0      80.0      130.0        100.0     100.0      300.0
# TXN           NaN       NaN        NaN        500.0      15.0       23.0
# WMT          40.0      55.0       70.0          NaN       NaN        NaN
#
#       Shares_2018  Low_2018  High_2018
# AAPL         40.0     135.0      170.0
# AMZN          8.0     900.0     1125.0
# GE            NaN       NaN        NaN
# IBM           NaN       NaN        NaN
# SLB           NaN       NaN        NaN
# TSLA         50.0     220.0      400.0
# TXN           NaN       NaN        NaN
# WMT           NaN       NaN        NaN

# %%
stock_join.equals(stock_concat)
# Out:
# True

# %%
names = ['prices', 'transactions']

# %%
food_tables = [pd.read_csv('data/food_{}.csv'.format(name)) for name in names]
food_tables
# Out:
# [     item store  price  Date
#  0    pear     A   0.99  2017
#  1    pear     B   1.99  2017
#  2   peach     A   2.99  2017
#  3   peach     B   3.49  2017
#  4  banana     A   0.39  2017
#  5  banana     B   0.49  2017
#  6   steak     A   5.99  2017
#  7   steak     B   6.99  2017
#  8   steak     B   4.99  2015,    custid     item store  quantity
#  0       1     pear     A         5
#  1       1   banana     A        10
#  2       2    steak     B         3
#  3       2     pear     B         1
#  4       2    peach     B         2
#  5       2    steak     B         1
#  6       2  coconut     B         4]

# %%
food_tables[0]
# Out:
#      item store  price  Date
# 0    pear     A   0.99  2017
# 1    pear     B   1.99  2017
# 2   peach     A   2.99  2017
# 3   peach     B   3.49  2017
# 4  banana     A   0.39  2017
# 5  banana     B   0.49  2017
# 6   steak     A   5.99  2017
# 7   steak     B   6.99  2017
# 8   steak     B   4.99  2015

# %%
food_tables[1]
# Out:
#    custid     item store  quantity
# 0       1     pear     A         5
# 1       1   banana     A        10
# 2       2    steak     B         3
# 3       2     pear     B         1
# 4       2    peach     B         2
# 5       2    steak     B         1
# 6       2  coconut     B         4

# %%
food_prices, food_transactions = food_tables

# %%
display_frames(food_tables, 30)
# Out:
# <table style = "display: inline;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item</th>
#       <th>store</th>
#       <th>price</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>pear</td>
#       <td>A</td>
#       <td>0.99</td>
#       <td>2017</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>pear</td>
#       <td>B</td>
#       <td>1.99</td>
#       <td>2017</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>peach</td>
#       <td>A</td>
#       <td>2.99</td>
#       <td>2017</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>peach</td>
#       <td>B</td>
#       <td>3.49</td>
#       <td>2017</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>banana</td>
#       <td>A</td>
#       <td>0.39</td>
#       <td>2017</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>banana</td>
#       <td>B</td>
#       <td>0.49</td>
#       <td>2017</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>steak</td>
#       <td>A</td>
#       <td>5.99</td>
#       <td>2017</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>steak</td>
#       <td>B</td>
#       <td>6.99</td>
#       <td>2017</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>steak</td>
#       <td>B</td>
#       <td>4.99</td>
#       <td>2015</td>
#     </tr>
#   </tbody>
# </table>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<table style = "display: inline;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>custid</th>
#       <th>item</th>
#       <th>store</th>
#       <th>quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>pear</td>
#       <td>A</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>banana</td>
#       <td>A</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>steak</td>
#       <td>B</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>pear</td>
#       <td>B</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>peach</td>
#       <td>B</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>steak</td>
#       <td>B</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2</td>
#       <td>coconut</td>
#       <td>B</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %%
food_transactions.merge(food_prices,
                        on = ['item', 'store'])
# Out:
#    custid    item store  quantity  price  Date
# 0       1    pear     A         5   0.99  2017
# 1       1  banana     A        10   0.39  2017
# 2       2   steak     B         3   6.99  2017
# 3       2   steak     B         3   4.99  2015
# 4       2   steak     B         1   6.99  2017
# 5       2   steak     B         1   4.99  2015
# 6       2    pear     B         1   1.99  2017
# 7       2   peach     B         2   3.49  2017

# %%
food_prices.query('Date == 2017')
# Out:
#      item store  price  Date
# 0    pear     A   0.99  2017
# 1    pear     B   1.99  2017
# 2   peach     A   2.99  2017
# 3   peach     B   3.49  2017
# 4  banana     A   0.39  2017
# 5  banana     B   0.49  2017
# 6   steak     A   5.99  2017
# 7   steak     B   6.99  2017

# %%
food_transactions.merge(food_prices.query('Date == 2017'),
                        how = 'left')
# Out:
#    custid     item store  quantity  price    Date
# 0       1     pear     A         5   0.99  2017.0
# 1       1   banana     A        10   0.39  2017.0
# 2       2    steak     B         3   6.99  2017.0
# 3       2     pear     B         1   1.99  2017.0
# 4       2    peach     B         2   3.49  2017.0
# 5       2    steak     B         1   6.99  2017.0
# 6       2  coconut     B         4    NaN     NaN

# %%
food_prices.query('Date == 2017').set_index(['item', 'store'])
# Out:
#               price  Date
# item   store
# pear   A       0.99  2017
#        B       1.99  2017
# peach  A       2.99  2017
#        B       3.49  2017
# banana A       0.39  2017
#        B       0.49  2017
# steak  A       5.99  2017
#        B       6.99  2017

# %%
food_prices_join = food_prices.query('Date == 2017')\
                              .set_index(['item', 'store'])
food_prices_join
# Out:
#               price  Date
# item   store
# pear   A       0.99  2017
#        B       1.99  2017
# peach  A       2.99  2017
#        B       3.49  2017
# banana A       0.39  2017
#        B       0.49  2017
# steak  A       5.99  2017
#        B       6.99  2017

# %%
food_transactions.join(food_prices_join,
                       on = ['item', 'store'])
# Out:
#    custid     item store  quantity  price    Date
# 0       1     pear     A         5   0.99  2017.0
# 1       1   banana     A        10   0.39  2017.0
# 2       2    steak     B         3   6.99  2017.0
# 3       2     pear     B         1   1.99  2017.0
# 4       2    peach     B         2   3.49  2017.0
# 5       2    steak     B         1   6.99  2017.0
# 6       2  coconut     B         4    NaN     NaN

# %%
import glob
df_list = []
for filename in glob.glob('*/gas prices/*.csv'):
#     print(filename)
    df_list.append(pd.read_csv(filename,
                               index_col = 'Week',
                               parse_dates = ['Week']))

# %%
gas = pd.concat(df_list, axis = 'columns')
gas.head()
# Out:
#             Diesel  All Grades  Midgrade  Premium  Regular
# Week
# 2017-09-25   2.788       2.701     2.859    3.105    2.583
# 2017-09-18   2.791       2.750     2.906    3.151    2.634
# 2017-09-11   2.802       2.800     2.953    3.197    2.685
# 2017-09-04   2.758       2.794     2.946    3.191    2.679
# 2017-08-28   2.605       2.513     2.668    2.901    2.399

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///data/chinook.db')

# %%
tracks = pd.read_sql_table('tracks', engine)
tracks.head()
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# 1   5510424       0.99
# 2   3990994       0.99
# 3   4331779       0.99
# 4   6290521       0.99

# %%
genres = pd.read_sql_table('genres', engine)
genres.head()
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll

# %%
genre_track = genres.merge(tracks[['GenreId', 'Milliseconds']],
                           on = 'GenreId',
                           how = 'left')
genre_track.head()
# Out:
#    GenreId  Name  Milliseconds
# 0        1  Rock        343719
# 1        1  Rock        342562
# 2        1  Rock        230619
# 3        1  Rock        252051
# 4        1  Rock        375418

# %%
genre_time = genre_track.groupby('Name')['Milliseconds'].mean()
genre_time
# Out:
# Name
# Alternative           2.640585e+05
# Alternative & Punk    2.343538e+05
# Blues                 2.703598e+05
# Bossa Nova            2.195900e+05
# Classical             2.938676e+05
# Comedy                1.585264e+06
# Drama                 2.575284e+06
# Easy Listening        1.891642e+05
# Electronica/Dance     3.029858e+05
# Heavy Metal           2.974529e+05
# Hip Hop/Rap           1.781763e+05
# Jazz                  2.917554e+05
# Latin                 2.328593e+05
# Metal                 3.097494e+05
# Opera                 1.748130e+05
# Pop                   2.290341e+05
# R&B/Soul              2.200669e+05
# Reggae                2.471778e+05
# Rock                  2.839100e+05
# Rock And Roll         1.346435e+05
# Sci Fi & Fantasy      2.911783e+06
# Science Fiction       2.625549e+06
# Soundtrack            2.443709e+05
# TV Shows              2.145041e+06
# World                 2.249238e+05
# Name: Milliseconds, dtype: float64

# %%
pd.to_timedelta(genre_time, unit = 'ms').sort_values().dt.floor('s')
# Out:
# Name
# Rock And Roll        00:02:14
# Opera                00:02:54
# Hip Hop/Rap          00:02:58
# Easy Listening       00:03:09
# Bossa Nova           00:03:39
# R&B/Soul             00:03:40
# World                00:03:44
# Pop                  00:03:49
# Latin                00:03:52
# Alternative & Punk   00:03:54
# Soundtrack           00:04:04
# Reggae               00:04:07
# Alternative          00:04:24
# Blues                00:04:30
# Rock                 00:04:43
# Jazz                 00:04:51
# Classical            00:04:53
# Heavy Metal          00:04:57
# Electronica/Dance    00:05:02
# Metal                00:05:09
# Comedy               00:26:25
# TV Shows             00:35:45
# Drama                00:42:55
# Science Fiction      00:43:45
# Sci Fi & Fantasy     00:48:31
# Name: Milliseconds, dtype: timedelta64[ns]

# %%
cust = pd.read_sql_table('customers',
                         engine,
                         columns = ['CustomerId', 'FirstName', 'LastName'])
cust.head()
# Out:
#    CustomerId  FirstName     LastName
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová

# %%
invoice = pd.read_sql_table('invoices',
                            engine,
                            columns = ['InvoiceId', 'CustomerId'])
invoice.head()
# Out:
#    InvoiceId  CustomerId
# 0         98           1
# 1        121           1
# 2        143           1
# 3        195           1
# 4        316           1

# %%
ii = pd.read_sql_table('invoice_items',
                       engine,
                       columns = ['InvoiceId', 'UnitPrice', 'Quantity'])
ii.head()
# Out:
#    InvoiceId  UnitPrice  Quantity
# 0          1       0.99         1
# 1          1       0.99         1
# 2          2       0.99         1
# 3          2       0.99         1
# 4          2       0.99         1

# %%
cust_inv = cust.merge(invoice, on='CustomerId')
cust_inv.head(9)
# Out:
#    CustomerId FirstName   LastName  InvoiceId
# 0           1      Luís  Gonçalves         98
# 1           1      Luís  Gonçalves        121
# 2           1      Luís  Gonçalves        143
# 3           1      Luís  Gonçalves        195
# 4           1      Luís  Gonçalves        316
# 5           1      Luís  Gonçalves        327
# 6           1      Luís  Gonçalves        382
# 7           2    Leonie     Köhler          1
# 8           2    Leonie     Köhler         12

# %%
cust_inv = cust.merge(invoice, on='CustomerId')\
               .merge(ii, on = 'InvoiceId')
cust_inv.head(8)
# Out:
#    CustomerId FirstName   LastName  InvoiceId  UnitPrice  Quantity
# 0           1      Luís  Gonçalves         98       1.99         1
# 1           1      Luís  Gonçalves         98       1.99         1
# 2           1      Luís  Gonçalves        121       0.99         1
# 3           1      Luís  Gonçalves        121       0.99         1
# 4           1      Luís  Gonçalves        121       0.99         1
# 5           1      Luís  Gonçalves        121       0.99         1
# 6           1      Luís  Gonçalves        143       0.99         1
# 7           1      Luís  Gonçalves        143       0.99         1

# %%
cust_inv['Total'] = cust_inv['Quantity'] * cust_inv['UnitPrice']
cols = ['CustomerId', 'FirstName', 'LastName']
# cust_inv.assign(Total = total)
cust_inv.head(8)
# Out:
#    CustomerId FirstName   LastName  InvoiceId  UnitPrice  Quantity  Total
# 0           1      Luís  Gonçalves         98       1.99         1   1.99
# 1           1      Luís  Gonçalves         98       1.99         1   1.99
# 2           1      Luís  Gonçalves        121       0.99         1   0.99
# 3           1      Luís  Gonçalves        121       0.99         1   0.99
# 4           1      Luís  Gonçalves        121       0.99         1   0.99
# 5           1      Luís  Gonçalves        121       0.99         1   0.99
# 6           1      Luís  Gonçalves        143       0.99         1   0.99
# 7           1      Luís  Gonçalves        143       0.99         1   0.99

# %%
cust_inv.groupby(cols)['Total'].sum()\
                               .sort_values(ascending = False)\
                               .head()
# Out:
# CustomerId  FirstName  LastName
# 6           Helena     Holý          49.62
# 26          Richard    Cunningham    47.62
# 57          Luis       Rojas         46.62
# 46          Hugh       O'Reilly      45.62
# 45          Ladislav   Kovács        45.62
# Name: Total, dtype: float64

# %%
sql_string1 = '''
    select 
        Name, 
        time(avg(Milliseconds) / 1000, 'unixepoch') as avg_time
    from (
            select 
                g.Name, 
                t.Milliseconds
            from 
                genres as g 
            join
                tracks as t
                on 
                    g.genreid == t.genreid
         )
    group by 
        Name
    order by 
         avg_time
'''

pd.read_sql_query(sql_string1, engine)
# Out:
#                   Name  avg_time
# 0        Rock And Roll  00:02:14
# 1                Opera  00:02:54
# 2          Hip Hop/Rap  00:02:58
# 3       Easy Listening  00:03:09
# 4           Bossa Nova  00:03:39
# 5             R&B/Soul  00:03:40
# 6                World  00:03:44
# 7                  Pop  00:03:49
# 8                Latin  00:03:52
# 9   Alternative & Punk  00:03:54
# 10          Soundtrack  00:04:04
# 11              Reggae  00:04:07
# 12         Alternative  00:04:24
# 13               Blues  00:04:30
# 14                Rock  00:04:43
# 15                Jazz  00:04:51
# 16           Classical  00:04:53
# 17         Heavy Metal  00:04:57
# 18   Electronica/Dance  00:05:02
# 19               Metal  00:05:09
# 20              Comedy  00:26:25
# 21            TV Shows  00:35:45
# 22               Drama  00:42:55
# 23     Science Fiction  00:43:45
# 24    Sci Fi & Fantasy  00:48:31

# %%
>>> sql_string2 = '''
    select 
          c.customerid, 
          c.FirstName, 
          c.LastName, 
          sum(ii.quantity * ii.unitprice) as Total
    from
         customers as c
    join
         invoices as i
              on c.customerid = i.customerid
    join
        invoice_items as ii
              on i.invoiceid = ii.invoiceid
    group by
        c.customerid, c.FirstName, c.LastName
    order by
        Total desc
'''
>>> pd.read_sql_query(sql_string2, engine)
# Out:
#     CustomerId  FirstName      LastName  Total
# 0            6     Helena          Holý  49.62
# 1           26    Richard    Cunningham  47.62
# 2           57       Luis         Rojas  46.62
# 3           45   Ladislav        Kovács  45.62
# 4           46       Hugh      O'Reilly  45.62
# 5           37       Fynn    Zimmermann  43.62
# 6           24      Frank       Ralston  43.62
# 7           28      Julia       Barnett  43.62
# 8           25     Victor       Stevens  42.62
# 9            7     Astrid        Gruber  42.62
# 10          44      Terhi    Hämäläinen  41.62
# 11           5  František   Wichterlová  40.62
# 12          43   Isabelle       Mercier  40.62
# 13          48   Johannes  Van der Berg  40.62
# 14          20        Dan        Miller  39.62
# 15          34       João     Fernandes  39.62
# 16           1       Luís     Gonçalves  39.62
# 17           3   François      Tremblay  39.62
# 18           4      Bjørn        Hansen  39.62
# 19          17       Jack         Smith  39.62
# 20          22    Heather       Leacock  39.62
# 21          42      Wyatt        Girard  39.62
# 22          15   Jennifer      Peterson  38.62
# 23          19        Tim         Goyer  38.62
# 24          39    Camille       Bernard  38.62
# 25          40  Dominique      Lefebvre  38.62
# 26          51     Joakim     Johansson  38.62
# 27          58      Manoj        Pareek  38.62
# 28           2     Leonie        Köhler  37.62
# 29           8       Daan       Peeters  37.62
# 30           9       Kara       Nielsen  37.62
# 31          10    Eduardo       Martins  37.62
# 32          11  Alexandre         Rocha  37.62
# 33          12    Roberto       Almeida  37.62
# 34          13   Fernanda         Ramos  37.62
# 35          14       Mark       Philips  37.62
# 36          16      Frank        Harris  37.62
# 37          18   Michelle        Brooks  37.62
# 38          21      Kathy         Chase  37.62
# 39          23       John        Gordon  37.62
# 40          27    Patrick          Gray  37.62
# 41          29     Robert         Brown  37.62
# 42          30     Edward       Francis  37.62
# 43          31     Martha          Silk  37.62
# 44          32      Aaron      Mitchell  37.62
# 45          33      Ellie      Sullivan  37.62
# 46          35   Madalena       Sampaio  37.62
# 47          36     Hannah     Schneider  37.62
# 48          38     Niklas      Schröder  37.62
# 49          41       Marc        Dubois  37.62
# 50          47      Lucas       Mancini  37.62
# 51          49  Stanisław        Wójcik  37.62
# 52          50    Enrique         Muñoz  37.62
# 53          52       Emma         Jones  37.62
# 54          53       Phil        Hughes  37.62
# 55          54      Steve        Murray  37.62
# 56          55       Mark        Taylor  37.62
# 57          56      Diego     Gutiérrez  37.62
# 58          59       Puja    Srivastava  36.64

# %%
import pandas as pd

# %%
crime_sort = pd.read_hdf('data/crime.h5', 'crime') \
                   .set_index('REPORTED_DATE') \
                   .sort_index()
crime_sort.head()
# Out:
#                                     OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault  aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order    all-other-crimes
# 2012-01-02 00:16:00       traffic-accident-dui-duid    traffic-accident
# 2012-01-02 00:47:00                traffic-accident    traffic-accident
# 2012-01-02 01:35:00              aggravated-assault  aggravated-assault
#
#                         GEO_LON    GEO_LAT NEIGHBORHOOD_ID  IS_CRIME  \
# REPORTED_DATE
# 2012-01-02 00:06:00 -104.816860  39.796717       montbello         1
# 2012-01-02 00:06:00 -104.816860  39.796717       montbello         1
# 2012-01-02 00:16:00 -104.971851  39.736874   cheesman-park         0
# 2012-01-02 00:47:00 -104.951824  39.740168   congress-park         0
# 2012-01-02 01:35:00 -104.998131  39.749922   union-station         1
#
#                      IS_TRAFFIC
# REPORTED_DATE
# 2012-01-02 00:06:00           0
# 2012-01-02 00:06:00           0
# 2012-01-02 00:16:00           1
# 2012-01-02 00:47:00           1
# 2012-01-02 01:35:00           0

# %%
crime_sort.resample('W')
# Out:
# DatetimeIndexResampler [freq=<Week: weekday=6>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
weekly_crimes = crime_sort.resample('W').size()

# %%
weekly_crimes.head()
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
# Freq: W-SUN, dtype: int64

# %%
len(crime_sort.loc[:'2012-1-8'])
# Out:
# 877

# %%
len(crime_sort.loc['2012-1-9':'2012-1-15'])
# Out:
# 1071

# %%
crime_sort.resample('W-THU').size().head()
# Out:
# REPORTED_DATE
# 2012-01-05     462
# 2012-01-12    1116
# 2012-01-19     924
# 2012-01-26    1061
# 2012-02-02     926
# Freq: W-THU, dtype: int64

# %%
crime_sort.loc[:'2012-1-5'].size
# Out:
# 3234

# %%
weekly_crimes_gby = crime_sort.groupby(pd.Grouper(freq = 'W'))\
                              .size()
weekly_crimes_gby.head()
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
# Freq: W-SUN, dtype: int64

# %%
dir(crime_sort.resample('W'))
# Out:
# ['GEO_LAT',
#  'GEO_LON',
#  'IS_CRIME',
#  'IS_TRAFFIC',
#  'NEIGHBORHOOD_ID',
#  'OFFENSE_CATEGORY_ID',
#  'OFFENSE_TYPE_ID',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_accessors',
#  '_adjust_binner_for_upsample',
#  '_agg_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_apply_filter',
#  '_apply_loffset',
#  '_apply_whitelist',
#  '_assure_grouper',
#  '_attributes',
#  '_builtin_table',
#  '_concat_objects',
#  '_constructor',
#  '_convert_obj',
#  '_cumcount_array',
#  '_cython_agg_general',
#  '_cython_table',
#  '_cython_transform',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_downsample',
#  '_from_selection',
#  '_get_binner',
#  '_get_binner_for_time',
#  '_get_index',
#  '_get_indices',
#  '_get_resampler_for_grouping',
#  '_gotitem',
#  '_group_selection',
#  '_groupby_and_aggregate',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cython_func',
#  '_iterate_slices',
#  '_make_wrapper',
#  '_obj_with_exclusions',
#  '_python_agg_general',
#  '_python_apply_general',
#  '_resampler_for_grouping',
#  '_reset_cache',
#  '_reset_group_selection',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_set_binner',
#  '_set_group_selection',
#  '_set_result_index_ordered',
#  '_shallow_copy',
#  '_transform_should_cast',
#  '_try_aggregate_string_function',
#  '_try_cast',
#  '_typ',
#  '_upsample',
#  '_wrap_applied_output',
#  '_wrap_result',
#  'agg',
#  'aggregate',
#  'apply',
#  'asfreq',
#  'ax',
#  'backfill',
#  'bfill',
#  'count',
#  'ffill',
#  'fillna',
#  'first',
#  'get_group',
#  'groups',
#  'indices',
#  'interpolate',
#  'last',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'ndim',
#  'nearest',
#  'ngroups',
#  'nunique',
#  'obj',
#  'ohlc',
#  'pad',
#  'pipe',
#  'plot',
#  'prod',
#  'sem',
#  'size',
#  'std',
#  'sum',
#  'transform',
#  'var']

# %%
crime = pd.read_hdf('data/crime.h5', 'crime')
crime.head()
# Out:
#               OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID       REPORTED_DATE  \
# 0   traffic-accident-dui-duid    traffic-accident 2014-06-29 02:01:00
# 1  vehicular-eluding-no-chase    all-other-crimes 2014-06-29 01:54:00
# 2        disturbing-the-peace     public-disorder 2014-06-29 02:00:00
# 3                      curfew     public-disorder 2014-06-29 02:18:00
# 4          aggravated-assault  aggravated-assault 2014-06-29 04:17:00
#
#       GEO_LON    GEO_LAT            NEIGHBORHOOD_ID  IS_CRIME  IS_TRAFFIC
# 0 -105.000149  39.745753                        cbd         0           1
# 1 -104.884660  39.738702                east-colfax         1           0
# 2 -105.020719  39.706674                athmar-park         1           0
# 3 -105.001552  39.769505                  sunnyside         1           0
# 4 -105.018557  39.679229  college-view-south-platte         1           0

# %%
weekly_crimes2 = crime.resample('W',
                                on = 'REPORTED_DATE').size()
weekly_crimes2.head()
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
# Freq: W-SUN, dtype: int64

# %%
weekly_crimes2.equals(weekly_crimes)
# Out:
# True

# %%
weekly_crimes_gby2 = crime.groupby(pd.Grouper(key = 'REPORTED_DATE',
                                              freq = 'W')).size()
weekly_crimes_gby2.head()
# Out:
# REPORTED_DATE
# 2012-01-08     877
# 2012-01-15    1071
# 2012-01-22     991
# 2012-01-29     988
# 2012-02-05     888
# Freq: W-SUN, dtype: int64

# %%
weekly_crimes_gby2.equals(weekly_crimes_gby)
# Out:
# True

# %%
weekly_crimes.plot(figsize = (16,4),
                   title = 'All Denver Crimes');

# %%
crime_sort = pd.read_hdf('data/crime.h5',
                         'crime')\
               .set_index('REPORTED_DATE')\
               .sort_index()
crime_sort.head()
# Out:
#                                     OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2012-01-02 00:06:00              aggravated-assault  aggravated-assault
# 2012-01-02 00:06:00  violation-of-restraining-order    all-other-crimes
# 2012-01-02 00:16:00       traffic-accident-dui-duid    traffic-accident
# 2012-01-02 00:47:00                traffic-accident    traffic-accident
# 2012-01-02 01:35:00              aggravated-assault  aggravated-assault
#
#                         GEO_LON    GEO_LAT NEIGHBORHOOD_ID  IS_CRIME  \
# REPORTED_DATE
# 2012-01-02 00:06:00 -104.816860  39.796717       montbello         1
# 2012-01-02 00:06:00 -104.816860  39.796717       montbello         1
# 2012-01-02 00:16:00 -104.971851  39.736874   cheesman-park         0
# 2012-01-02 00:47:00 -104.951824  39.740168   congress-park         0
# 2012-01-02 01:35:00 -104.998131  39.749922   union-station         1
#
#                      IS_TRAFFIC
# REPORTED_DATE
# 2012-01-02 00:06:00           0
# 2012-01-02 00:06:00           0
# 2012-01-02 00:16:00           1
# 2012-01-02 00:47:00           1
# 2012-01-02 01:35:00           0

# %%
crime_quarterly = crime_sort.resample('Q')['IS_CRIME',
                                        'IS_TRAFFIC'].sum()
crime_quarterly.head()
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-03-31         7882        4726
# 2012-06-30         9641        5255
# 2012-09-30        10566        5003
# 2012-12-31         9197        4802
# 2013-03-31         8730        4442

# %%
crime_sort.resample('QS')['IS_CRIME','IS_TRAFFIC'].sum()\
          .head()
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-01-01         7882        4726
# 2012-04-01         9641        5255
# 2012-07-01        10566        5003
# 2012-10-01         9197        4802
# 2013-01-01         8730        4442

# %%
crime_sort.loc['2012-04-01':'2012-06-30',['IS_CRIME',
                                          'IS_TRAFFIC']]\
          .sum()
# Out:
# IS_CRIME      9641
# IS_TRAFFIC    5255
# dtype: int64

# %%
crime_quarterly2 = crime_sort.groupby(pd.Grouper(freq = 'Q'))\
                              ['IS_CRIME','IS_TRAFFIC'].sum()

crime_quarterly2.head()
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2012-03-31         7882        4726
# 2012-06-30         9641        5255
# 2012-09-30        10566        5003
# 2012-12-31         9197        4802
# 2013-03-31         8730        4442

# %%
crime_quarterly2.equals(crime_quarterly)
# Out:
# True

# %%
plot_kwargs = dict(figsize = (16,4),
                   color = ['black', 'lightgrey'],
            title = 'Denver Crimes and Traffic Accidents')

# %%
crime_quarterly.plot(**plot_kwargs);

# %%
crime_begin = crime_quarterly.iloc[0]
crime_begin
# Out:
# IS_CRIME      7882
# IS_TRAFFIC    4726
# Name: 2012-03-31 00:00:00, dtype: int64

# %%
crime_quarterly.div(crime_begin)\
               .sub(1)\
               .round(2)\
               .plot(**plot_kwargs);
